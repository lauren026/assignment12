# %% [markdown]
# # 20143750 KIM SU BIN

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Define the function.

# %%
num     = 1001
std     = 5 

def fun(x):
 
    f = np.abs(x) * np.sin(x)

    return f

# %% [markdown]
# And set the variables to use.

# %%
n       = np.random.rand(num)
nn      = n - np.mean(n)
x       = np.linspace(-10,10,num)
y1      = fun(x) # clean points
y2      = y1 + nn * std # noisy points

# %%
plt.title('Clean Data')
plt.plot(x, y1, 'b.')
plt.show()

# %% [markdown]
# The above graph is about to clean data.

# %%
plt.title('Noisy Data')
plt.plot(x, y2, 'r.')
plt.show()

# %% [markdown]
# And, The above graph is about to noisy data.

# %%
def leastSquare(x, y, a):

    n = np.zeros((a+1, num))
    
    
    for i in range(0,a+1):
        n[i] = np.array([x ** i])
    n = n.T

    inv = np.dot(np.linalg.inv(np.dot(n.T, n)), n.T)
    
    return np.dot(inv, y)

# %% [markdown]
# This is the leastSquare function.

# %%
for i in range(6, 16):
    plt.title('Least Square Approximation : %d' %i)
    p = leastSquare(x, y2, i)
    
    a = 0
    for j in range(0, i+1):
        a += p[j] * x ** j
    
    err = y1 - a
    err = err ** 2
    
    plt.title('Error p : %d' %i)
    plt.plot(x, a, 'k.', x, err, 'g.')
    plt.show()

# %% [markdown]
# The polynomial curves that fit the noisy data by the least square error with varying.

# %%
i=[1/8, 1/4, 1/2, 1, 2, 4, 8]
for k in i:
    p = leastSquare(x, y2, k)
    
    a = 0
    for j in range(0, k+1):
        a += p[j] * x ** j
    
    err = y1 - a
    err = err ** 2
    
    plt.title('Error p : %d' %k)
    plt.plot(x, a, 'k.', x, err, 'g.')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e152f72ea905> in <module>()
#       1 i=[1/8, 1/4, 1/2, 1, 2, 4, 8]
#       2 for k in i:
# ----> 3     p = leastSquare(x, y2, k)
#       4
#       5     a = 0
#
# <ipython-input-13-f557812fb6da> in leastSquare(x, y, p)
#       1 def leastSquare(x, y, p):
#       2
# ----> 3     n_x = np.zeros((p+1, num))
#       4     for i in range(0,p+1):
#       5         n_x[i] = np.array([x ** i])
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# I want to apply it for 1/8, 1/4, 1/2, 1, 2, 4, 8.. But I failed.

# %% [markdown]
# ## My github address: https://github.com/lauren026/assignment12
